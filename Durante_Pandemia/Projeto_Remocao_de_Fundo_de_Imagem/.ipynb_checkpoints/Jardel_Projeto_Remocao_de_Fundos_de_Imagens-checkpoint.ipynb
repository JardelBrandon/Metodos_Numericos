# %% [markdown]
# **<p>Disciplina:** Métodos Numéricos</p>
# **<p>Semestre:** 2020.2</p>
# **<p>Aluno:** Jardel Brandon de Araujo Regis</p>
# **<p>Mátricula:** 201621250014</p>
# **<p>2ª Unidade:** Álgebra Linear Computacional</p>
#
# ---
# # <center>Projeto - 1</center>
# ## <center>Remoção de fundo com PCA robusto</center>
# ---

# %% [markdown]
# ## Base de dados

# %% [markdown]
# Vamos usar o conjunto de dados de vídeo real 003 do [BMC 2012 Background Models Challenge Dataset](http://bmc.iut-auvergne.com/?page_id=24)
#
# Outras fontes de conjuntos de dados:
#
# - [Conjuntos de dados de vídeo de atividade humana](https://www.cs.utexas.edu/~chaoyeh/web_action_data/dataset_list.html)
# - [Site de subtração de plano de fundo](https://sites.google.com/site/backgroundsubtraction/test-sequences) (alguns links neste site estão corrompidos / desatualizados, mas muitos funcionam)

# %%
import moviepy.editor as mpe
# from IPython.display import display
from glob import glob
from PIL import Image
from skimage.transform import resize

# %%
import sys, os
import numpy as np
import scipy.misc
import scipy

# %%
# %matplotlib inline
import matplotlib.pyplot as plt

# %%
# MAX_ITERS = 10
TOL = 1.0e-8

# %%
video = mpe.VideoFileClip('data/download.avi') # https://github.com/momonala/image-processing-projects/blob/master/background_removal/video/Video_003/Video_003.avi

# %%
video.subclip(0,50).ipython_display(width=300)
# Out:
# t:   0%|                                                                             | 0/350 [00:00<?, ?it/s, now=None]
# Moviepy - Building video __temp__.mp4.
# Moviepy - Writing video __temp__.mp4
# Moviepy - Done !
# Moviepy - video ready __temp__.mp4
# <div align=middle><video width='300'src='data:video/mp4;base64,...' controls>Sorry, seems like your browser doesn't support HTML5 audio/video</video></div>

# %%
video.duration
# Out:
# 113.57

# %% [markdown]
# ### Métodos auxiliares

# %%
def create_data_matrix_from_video(clip, k=5, scale=50):
    return np.vstack([rescale(rgb2gray(clip.get_frame(i/float(k))).astype(int), 
                      scale).flatten() for i in range(k * int(clip.duration))]).T

# %%
def create_data_matrix_from_video(clip, k, scale):
    frames = []
    for i in range(k * int(clip.duration)):
        frame = clip.get_frame(i / float(k))
        frame = rgb2gray(frame).astype(int)
        image = Image.fromarray(frame)
        size = tuple((np.array(image.size) * scale).astype(int))
        scaled_image = np.array(image.resize(size)).flatten()
        frames.append(scaled_image)
    return np.vstack(frames).T # stack images horizontally

# %%
def create_data_matrix_from_video(clip, k, scale):
    frames = []
    for i in range(k * int(clip.duration)):
        frame = clip.get_frame(i / float(k))
        frame = rgb2gray(frame).astype(int)
        image = Image.fromarray(frame)
        size = tuple((np.array(image.size) * scale).astype(int))
        scaled_image = np.array(image.resize(size)).flatten()
        frames.append(scaled_image)
    return np.vstack(frames).T # stack images horizontally

# %%
def rgb2gray(rgb):
    return np.dot(rgb[...,:3], [0.299, 0.587, 0.114])

# %%
def plt_images(M, A, E, index_array, dims, filename=None):
    f = plt.figure(figsize=(15, 10))
    r = len(index_array)
    pics = r * 3
    for k, i in enumerate(index_array):
        for j, mat in enumerate([M, A, E]):
            sp = f.add_subplot(r, 3, 3*k + j + 1)
            sp.axis('Off')
            pixels = mat[:,i]
            if isinstance(pixels, scipy.sparse.csr_matrix):
                pixels = pixels.todense()
            plt.imshow(np.reshape(pixels, dims), cmap='gray')
    return f

# %%
def plots(ims, dims, figsize=(15,20), rows=1, interp=False, titles=None):
    if type(ims[0]) is np.ndarray:
        ims = np.array(ims)
    f = plt.figure(figsize=figsize)
    for i in range(len(ims)):
        sp = f.add_subplot(rows, len(ims)//rows, i+1)
        sp.axis('Off')
        plt.imshow(np.reshape(ims[i], dims), cmap="gray")

# %% [markdown]
# ### Carregamento e visualização os dados

# %% [markdown]
# Uma imagem de 1 momento no tempo tem 60 pixels por 80 pixels (quando dimensionada). Podemos * desenrolar * essa imagem em uma única coluna alta. Então, em vez de ter uma imagem 2D que é $ 60 \times 80 $, temos uma coluna $ 1 \times 4.800 $
#
# Isso não é muito legível, mas é útil porque permite empilhar as imagens de diferentes momentos umas sobre as outras, para colocar um vídeo todo em uma matriz. Se fosse pego a imagem do vídeo a cada décimo de segundo por 113 segundos (ou seja, 11.300 imagens diferentes, cada uma de um ponto no tempo diferente), teríamos uma matriz $ 11300 \times 4800 $, representando o vídeo!

# %%
fps = 100
scale = 25   # Adjust scale to change resolution of image
scale_percent = scale / 100

original_width = video.size[1]
original_height = video.size[0]

dims = (int(original_width * scale_percent), int(original_height * scale_percent))

# %%
M = create_data_matrix_from_video(video, fps, scale_percent)

# %%
print(dims, M.shape)
# Out:
# (60, 80) (4800, 11300)

# %%
plt.imshow(np.reshape(M[:,140], dims), cmap='gray');

# %% [markdown]
# Como `create_data_from_matrix` é um tanto lento, vamos salvar a matriz. Em geral, sempre que houver etapas de pré-processamento lentas, é uma boa ideia prática salvar os resultados para uso futuro

# %%
np.save("low_res_surveillance_matrix.npy", M)

# %% [markdown]
# Dessa forma é possível observar uma combinação linear (com pesos aleatórios) das colunas na matriz abaixo:

# %%
plt.figure(figsize=(12, 12))
plt.imshow(M, cmap='gray')

# %% [markdown]
# É como uma média ponderada aleatória. Se você pegar vários deles, acabará com colunas que são ou ortonormais entre si.

# %%
plt.imsave(fname="image1.jpg", arr=np.reshape(M[:,140], dims), cmap='gray')

# %% [markdown]
# ## Decomposição de valor singular (SVD)

# %% [markdown]
# Obviamente, esperaríamos que as palavras que aparecem com mais frequência em um tópico apareçam com menos frequência no outro - caso contrário, essa palavra não seria uma boa escolha para separar os dois tópicos. Portanto, esperamos que os tópicos sejam **ortogonais**.
# O algoritmo SVD fatoriza uma matriz em uma matriz com **colunas ortogonais** e outra com **linhas ortogonais** (junto com uma matriz diagonal, que contém a ** importância relativa ** de cada fator).
#
# <img src = "images/svd_fb.png" alt = "" style = "largura: 80%" />
# (fonte: [Facebook Research: Fast Randomized SVD] (https://research.fb.com/fast-randomized-svd))
#
# SVD é uma **decomposição exata**, pois as matrizes que ele cria são grandes o suficiente para cobrir totalmente a matriz original. SVD é extremamente usado em álgebra linear e, especificamente, em ciência de dados, incluindo: - análise semântica - filtragem / recomendações colaborativas ([entrada vencedora do Prêmio Netflix](https://datajobs.com/data-science-repo/Recommender-Systems-%5BNetflix%5D.pdf)) - calcular o pseudoinverso Moore-Penrose - compressão de dados - análise de componentes principais (será abordada posteriormente no curso)

# %% [markdown]
# ### Uma primeira abordagem com SVD

# %%
from sklearn import decomposition

# %%
u, s, v = decomposition.randomized_svd(M, 2)

# %%
u.shape, s.shape, v.shape
# Out:
# ((4800, 2), (2,), (2, 11300))

# %%
low_rank = u @ np.diag(s) @ v

# %%
low_rank.shape
# Out:
# (4800, 11300)

# %%
plt.figure(figsize=(12, 12))
plt.imshow(low_rank, cmap='gray')

# %%
plt.imshow(np.reshape(low_rank[:,140], dims), cmap='gray');

# %%
plt.imshow(np.reshape(M[:,550] - low_rank[:,550], dims), cmap='gray');

# %% [markdown]
# #### Aproximação de classificação 1

# %%
u, s, v = decomposition.randomized_svd(M, 1)

# %%
u.shape, s.shape, v.shape
# Out:
# ((4800, 1), (1,), (1, 11300))

# %%
low_rank = u @ np.diag(s) @ v

# %%
low_rank.shape
# Out:
# (4800, 11300)

# %%
plt.figure(figsize=(12, 12))
plt.imshow(low_rank, cmap='gray')

# %%
plt.imshow(np.reshape(M[:,550] - low_rank[:,550], dims), cmap='gray');

# %%
plt.imshow(np.reshape(M[:,140] - low_rank[:,140], dims), cmap='gray');

# %% [markdown]
# Let's zoom in on the people:

# %%
plt.imshow(np.reshape(M[:,140] - low_rank[:,140], dims)[10:40,30:70], cmap='gray');

# %%
plt.imshow(np.reshape(M[:,140], dims)[10:40,30:70], cmap='gray')

# %% [markdown]
# ## Principal Component Analysis (PCA)

# %% [markdown]
# Ao lidar com conjuntos de dados de alta dimensão, muitas vezes aproveitamos o fato de que os dados têm ** baixa dimensionalidade intrínseca ** para aliviar a maldição da dimensionalidade e da escala (talvez esteja em um subespaço de baixa dimensão ou em um variedade de baixa dimensão).
#
# [Análise de componente principal](http://setosa.io/ev/principal-component-analysis/) é útil para eliminar dimensões. A PCA clássica busca a melhor classificação - $ k $ estimativa $ L $ de $ M $ (minimizando $ \ | M - L \ | $ onde $ L $ tem classificação - $ k $). O SVD truncado faz esse cálculo! O PCA tradicional pode lidar com pequenos ruídos, mas é frágil em relação a observações grosseiramente corrompidas - até mesmo uma observação grosseiramente corrompida pode bagunçar significativamente a resposta. **PCA robusto** fatora uma matriz na soma de duas matrizes, $ M = L + S $, onde $ M $ é a matriz original, $ L $ é **baixa classificação** e $ S $ é **escasso**. Isso é o que usaremos para o problema de remoção de fundo! **Baixa classificação** significa que a matriz tem muitas informações redundantes - neste caso, é o fundo, que é o mesmo em todas as cenas (fale sobre informações redundantes!). **Sparse** significa que a matriz tem quase zero entradas - neste caso, veja como a imagem do primeiro plano (as pessoas) está quase vazia. (No caso de dados corrompidos, $ S $ está capturando as entradas corrompidas).

# %% [markdown]
# ### Aplicações de PCA  robusto
#
# - Fotos do **Reconhecimento facial**. O conjunto de dados aqui consiste em imagens de rostos de várias pessoas tiradas do mesmo ângulo, mas com diferentes iluminações.
# <img src = "images/faces_rpca.png" alt = "PCA robusto" style = "largura: 80%" />
# <img src = "images/faces_rpca_gross.png" alt = "PCA robusto" style = "largura: 80%" />
#
# - Indexação semântica latente: $ L $ captura palavras comuns usadas em todos os documentos, enquanto $ S $ captura as poucas palavras-chave que melhor distinguem cada documento dos outros
#
# - Classificação e filtragem colaborativa: uma pequena parte das classificações disponíveis pode ser ruidosa e até mesmo adulterada (consulte [Netflix RAD - Outlier Detection on Big Data](http://techblog.netflix.com/2015/02/rad-outlier-detection-on-big-data.html) no blog oficial netflix)

# %% [markdown]
# ### A norma L1 que induz esparsidade

# %% [markdown]
# A esfera unitária $ \lVert x \rVert_1 = 1 $ é um diamante na norma L1. Seus extremos são os cantos:

# %% [markdown]
#  <img src="images/L1vsL2.jpg" alt="L1 norm" style="width: 60%"/>
#
#  ([Fonte](https://www.quora.com/Why-is-L1-regularization-supposed-to-lead-to-sparsity-than-L2))
#
# Uma perspectiva semelhante é olhar para os *contornos* da função de perda:
#  <img src="images/L1vsL2_2.png" alt="L2 norm" style="width: 60%"/>
#  ([Fonte](https://www.quora.com/Why-is-L1-regularization-better-than-L2-regularization-provided-that-all-Norms-are-equivalent))

# %% [markdown]
# ### Problema de otimização

# %% [markdown]
# O PCA robusto pode ser escrito:
# $$ minimize \; \lVert L \rVert_ * + \lambda \lVert S \rVert_1 \\ subject \; to \; L + S = M $$
# Onde:
# - $ \lVert \cdot \rVert_1 $ é a **norma L1**. Minimizar a [norma L1](https://medium.com/@shiyan/l1-norm-regularization-and-sparsity-explained-for-dummies-5b0e4be3938a) resulta em valores esparsos. Para uma matriz, a norma L1 é igual à [norma de coluna máxima absoluta] (https://math.stackexchange.com/questions/519279/why-is-the-matrix-norm-a-1-maximum-absolute- coluna-soma-da-matriz).
#
# - $ \lVert \cdot \rVert_ * $ é a **norma nuclear**, que é a norma L1 dos valores singulares. Tentar minimizar isso resulta em valores singulares esparsos -> classificação baixa.

# %% [markdown]
# ### Implementando um algoritmo de um artigo

# %% [markdown]
# ####  Fontes
#
# Será utilizado o **algoritmo de busca do componente primário** geral deste [artigo robusto do PCA](https://arxiv.org/pdf/0912.3599.pdf)(Candes, Li, Ma, Wright), na forma específica de **Preenchimento da Matriz por meio do Método ALM Inexato** encontrado na [seção 3.1 deste documento](https://arxiv.org/pdf/1009.5055.pdf)(Lin, Chen, Ma). Também menciono as implementações encontradas [aqui](https://github.com/shriphani/robust_pcp/blob/master/robust_pcp.py) e
# [aqui](https://github.com/dfm/pcp/blob/master/pcp.py).

# %% [markdown]
# #### The Good Parts
#
# A seção 1 de Candes, Li, Ma, Wright é bem escrita, e a seção 5 Algoritmos é de principal interesse. **Não se faz necessário saber matemática ou compreender as provas para implementar um algoritmo de um papel.** Se faz necessário tentar coisas diferentes e vasculhar os recursos para obter informações úteis. Este campo tem mais pesquisadores teóricos e menos conselhos pragmáticos.
#
# O algoritmo é mostrado na página 29:
#
#  <img src="images/pcp_algorithm.png" alt="PCP algorithm" style="width: 100%"/>

# %% [markdown]
# Definições necessárias de $ \mathcal{S} $, o operador de redução, e $ \mathcal{D} $, o operador de limite de valor singular:
#
#  <img src="images/candes.png" alt="PCP algorithm" style="width: 100%"/>

# %% [markdown]
# A seção 3.1 de [Chen, Lin, Ma] () contém uma variação mais rápida diso:
#
#  <img src="images/rpca_inexact.png" alt="Inexact RPCA" style="width: 80%"/>
#
# E a Seção 4 tem alguns detalhes de implementação muito úteis sobre quantos valores singulares calcular (bem como escolher os valores dos parâmetros):
#
#  <img src="images/svp_value.png" alt="SVP values" style="width:70%"/>

# %% [markdown]
# ### Mais fontes para aprender mais sobre a teoria:
#
# - Otimização convexa por Stephen Boyd (Stanford Prof):
#  - [Vídeos OpenEdX](https://www.youtube.com/playlist?list=PLbBM_dvjud8oFj09MqqYnGSrT6zek42Q0)
#  -[Jupyter Notebooks](http://web.stanford.edu/~boyd/papers/cvx_short_course.html)
# - Método de direção alternada de multiplicadores (mais [Stephen Boyd](http://stanford.edu/~boyd/admm.html))

# %% [markdown]
# ## PCA robusto (via perseguição de componente primário)

# %% [markdown]
# ### Métodos auxiliares

# %% [markdown]
# Será utilizada a biblioteca [Fast Randomized PCA do Facebook](https://github.com/facebook/fbpca)..

# %%
from scipy import sparse
from sklearn.utils.extmath import randomized_svd
import fbpca

# %%
TOL=1e-9
MAX_ITERS=3

# %%
def converged(Z, d_norm):
    err = np.linalg.norm(Z, 'fro') / d_norm
    print('error: ', err)
    return err < TOL

# %%
def shrink(M, tau):
    S = np.abs(M) - tau
    return np.sign(M) * np.where(S>0, S, 0)

# %%
def _svd(M, rank): return fbpca.pca(M, k=min(rank, np.min(M.shape)), raw=True)

# %%
def norm_op(M): return _svd(M, 1)[1][0]

# %%
def svd_reconstruct(M, rank, min_sv):
    u, s, v = _svd(M, rank)
    s -= min_sv
    nnz = (s > 0).sum()
    return u[:,:nnz] @ np.diag(s[:nnz]) @ v[:nnz], nnz

# %%
def pcp(X, maxiter=10, k=10): # refactored
    m, n = X.shape
    trans = m<n
    if trans: X = X.T; m, n = X.shape
        
    lamda = 1/np.sqrt(m)
    op_norm = norm_op(X)
    Y = np.copy(X) / max(op_norm, np.linalg.norm( X, np.inf) / lamda)
    mu = k*1.25/op_norm; mu_bar = mu * 1e7; rho = k * 1.5
    
    d_norm = np.linalg.norm(X, 'fro')
    L = np.zeros_like(X); sv = 1
    
    examples = []
    
    for i in range(maxiter):
        print("rank sv:", sv)
        X2 = X + Y/mu
        
        S = shrink(X2 - L, lamda/mu)
        
        L, svp = svd_reconstruct(X2 - S, sv, 1/mu)
        
        sv = svp + (1 if svp < sv else round(0.05*n))
        
        Z = X - L - S
        Y += mu*Z; mu *= rho
        
        examples.extend([S[140,:], L[140,:]])
        
        if m > mu_bar: m = mu_bar
        if converged(Z, d_norm): break
    
    if trans: L=L.T; S=S.T
    return L, S, examples

# %% [markdown]
# O algoritmo novamente (página 29 de [Candes, Li, Ma e Wright](https://arxiv.org/pdf/0912.3599.pdf))
#
#  <img src="images/pcp_algorithm.png" alt="PCP algorithm" style="width: 100%"/>

# %% [markdown]
# ### Results

# %%
m, n = M.shape
round(m * .05)
# Out:
# 240

# %%
L, S, examples =  pcp(M, maxiter=5, k=10)
# Out:
# rank sv: 1
# error:  0.13722384924500203
# rank sv: 241
# error:  0.047680855330684765
# rank sv: 51
# error:  0.005883870395610021
# rank sv: 291
# error:  0.0005693738689123618
# rank sv: 531
# error:  2.490363629007151e-05

# %%
plots(examples, dims, rows=5)

# %%
f = plt_images(M, S, L, [140], dims)

# %%
np.save("high_res_L.npy", L)
np.save("high_res_S.npy", S)

# %%
f = plt_images(M, S, L, [0, 100, 1000], dims)

# %% [markdown]
# Como pode ser observado, extrair um pouco do primeiro plano é mais fácil do que identificar o fundo. Para obter o plano de fundo com precisão, é preciso remover todo o primeiro plano, não apenas partes dele

# %% [markdown]
# ## Fatoração LU

# %% [markdown]
# Ambos, `fbpca` e o próprio método escrito ` randomized_range_finder` usaram fatoração LU, que fatora uma matriz no produto de uma matriz triangular inferior e uma matriz triangular superior.

# %% [markdown]
# #### Eliminação gaussiana

# %% [markdown]
# Esta seção é baseada nas aulas 20-22 em Trefethen.

# %% [markdown]
# Caso, você não está familiarizado com a eliminação gaussiana ou precisa de uma atualização, segue uma fonte recomendada,  [vídeo da Khan Academy](https://pt.khanacademy.org/math/algebra-home/alg-matrices/alg-row-echelon-and-gaussian-elimination/v/matrices-reduced-row-echelon-form-2).

# %% [markdown]
# Vamos usar a Eliminação Gaussiana manualmente para revisar:
#
# A =
#  \begin{pmatrix}
#   1 & -2 & -2 & -3 \\
#   3 & -9 & 0 & -9 \\
#   -1 & 2 & 4 & 7  \\
#   -3 & -6 & 26 & 2
#  \end{pmatrix}

# %% [markdown]
# #### Resposta:

# %% [markdown]
# $$ LU = \begin{bmatrix} 1 & 0 & 0 & 0\\ 3 & 1 & 0 & 0 \\ -1 & 0 & 1 & 0 \\ -3 & 4 & -2 & 1\end{bmatrix} \cdot \begin{bmatrix} 1 & -2 & -2 & -3 \\ 0 & -3 & 6 & 0 \\ 0 & 0 & 2 & 4 \\ 0 & 0 & 0 & 1 \end{bmatrix}$$

# %% [markdown]
# O exemplo acima é das palestras 20, 21 de Trefethen.

# %% [markdown]
# **Eliminação Gaussiana** transforma um sistema linear em um triangular superior aplicando transformações lineares à esquerda.
# É a *triangularização triangular*.
#
# $$ L_ {m-1} \dots L_2 L_1 A = U $$
#
# L é *unidade triangular inferior* : todas as entradas diagonais são 1

# %%
def LU(A):
    U = np.copy(A)
    m, n = A.shape
    L = np.eye(n)
    for k in range(n-1):
        for j in range(k+1,n):
            L[j,k] = U[j,k]/U[k,k]
            U[j,k:n] -= L[j,k] * U[k,k:n]
    return L, U

# %%
A = np.array([[2,1,1,0],[4,3,3,1],[8,7,9,5],[6,7,9,8]]).astype(np.float)

# %%
L, U = LU(A)

# %%
np.allclose(A, L @ U)
# Out:
# True

# %% [markdown]
# A fatoração LU é útil. Resolver Ax = b torna-se LUx = b:
#
# 1. encontre A = LU
# 2. resolva Ly = b
# 3. resolva Ux = y

# %% [markdown]
# **Trabalho computacional**
#
# O Trabalho para a Eliminação Gaussiana é calculada como: $2\cdot\frac{1}{3} n^3$

# %% [markdown]
# **Memória**
#
# Acima, foram criadas duas novas matrizes, $ L $ e $ U $. No entanto, podemos armazenar os valores de $ L $ e $ U $ em uma matriz A (sobrescrevendo a matriz original). Visto que a diagonal de $ L $ é toda $ 1 $ s, ela não precisa ser armazenada. Fazer fatorações ou cálculos **local** é uma técnica comum em álgebra linear numérica para economizar memória. Observação: você não gostaria de fazer isso se precisasse usar sua matriz original $ A $ novamente no futuro.

# %% [markdown]
# Consider the matrix $$ A = \begin{bmatrix} 10^{-20} & 1 \\ 1 & 1 \end{bmatrix} $$

# %%
A = np.array([[1e-20, 1], [1,1]])

# %% [markdown]
# À mão, use a Eliminação Gaussiana para calcular o que L e U são:

# %% [markdown]
# #### Resposta

# %% [markdown]
# $$ L = \begin{bmatrix} 1 & 0 \\ 10^{20} & 1 \end{bmatrix} $$
# $$ U = \begin{bmatrix} 10^{-20} & 1 \\ 0 & 1-10^{-20} \end{bmatrix} $$

# %%
np.set_printoptions(suppress=True)

# %%
#Exercise:
L1 = np.array([[1, 0], [1e20, 1]])
U1 = np.array([[10e-20, 1], [0, 1-10e20]])

# %%
L2, U2 = LU(A)

# %%
L2, U2
# Out:
# (array([[1.e+00, 0.e+00],
#         [1.e+20, 1.e+00]]),
#  array([[ 1.e-20,  1.e+00],
#         [ 0.e+00, -1.e+20]]))

# %%
np.allclose(L1, L2)
# Out:
# True

# %%
np.allclose(U1, U2)
# Out:
# False

# %%
np.allclose(A, L2 @ U2)
# Out:
# False

# %% [markdown]
# Esta é a motivação para $ LU $ fatoração **com pivotamento**.
#
# Isso também ilustra que a fatoração LU é *estável*, mas não *estável para trás*. (Mesmo com pivotamento parcial, LU é "explosivamente instável" para certas matrizes, mas estável na prática)

# %% [markdown]
# #### Estabilidade

# %% [markdown]
# Um algoritmo $ \hat{f} $ para um problema $ f $ é **estável** se para cada $ x $,
# $$ \frac{\lVert \hat{f}(x) - f(y) \rVert}{ \lVert f(y) \rVert } = \mathcal{O}(\varepsilon_{máquina}) $$
#
# por cerca de $ y $ com
#
# $$ \frac{\lVert y - x \rVert }{\lVert x \rVert} = \mathcal{O}(\varepsilon_{máquina}) $$

# %% [markdown]
# **Um algoritmo estável fornece quase a resposta certa para quase a pergunta certa**
#
# Para traduzir isso:
# - pergunta certa: $ x $
# - a pergunta quase certa: $ y $
# - resposta certa: $ f $
# - resposta certa para a pergunta quase certa: $ f (y) $

# %% [markdown]
# ####  Estabilidade reversa

# %% [markdown]
# A estabilidade reversa é **mais forte** e **mais simples** do que a estabilidade.
# Um algoritmo $ \hat{f} $ para um problema $ f $ é **estável reversamente** se para cada $ x $,
# $$ \hat{f}(x) = f(y) $$
# por cerca de $ y $ com
# $$ \ frac {\lVert y - x \rVert} {\lVert x \rVert} = \mathcal{O} (\varepsilon_{máquina}) $$ **Um algoritmo estável reversamente dá exatamente a resposta certa para quase a pergunta certa**
#
# Resumindo:
# - pergunta certa: $ x $
# - a pergunta quase  certa: $ y $
# - resposta certa: $ f $
# - resposta certa para a pergunta quase certa: $ f (y) $
